# %%
# https://github.com/natasha/natasha
# https://github.com/natasha/navec

from navec import Navec
from razdel import tokenize, sentenize
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from funcs import *

navec = Navec.load('navec_hudlit_v1_12B_500K_300d_100q.tar')

# %%
df = pd.read_csv('test_corpus1.csv')
df = df[df['text'].notnull()]
sentiment_mapping = {'bad': 0, 'neutral': 1, 'good': 2}
df['target'] = df['coloring'].map(sentiment_mapping)
df['target'].value_counts()
# Out:
# 2    2120
# 0    1329
# 1     667
# Name: target, dtype: int64

# %% [markdown]
# ## Слова в данной библиотеке кодируются следующим образом.
#
# ## Убедимся, что король - мужчина + женщина = королева
#
# # ИМЕННО ЭТА ЯЧЕЙКА РАБОТАЕТ ДОЛГО

# %%
def print_nearest(vector, matrix, n=10):
    nearest_i = np.argsort(np.sum((matrix - vector)**2, axis=1))[:n]
    nearest = [navec.vocab.words[i] for i in nearest_i]
    print(nearest)

# navec.pq[navec.vocab.words.index(word)] == navec[word]
word = 'стол'
word_index = navec.vocab.words.index(word)
word_vec = navec[word]
print(f'Векторное представление слова "стол": {word_vec[:10]}')
navec_np = np.array([list(navec[word]) for word in navec.vocab.words])
# Out:
# Векторное представление слова "стол": [-0.2938254  -0.2968786  -0.02534253 -0.19875844  0.2802261  -0.14141266
#   0.05130551 -0.18968578  0.728676   -0.6062129 ]

# %% [markdown]
# ## Данная функция находит ближайшие слова к заданному вектору

# %%
print_nearest(navec['стол'], navec_np)
print_nearest(navec['король'], navec_np)
print_nearest(navec['король'] - navec['мужчина'] + navec['женщина'], navec_np)
# Out:
# ['стол', 'стола', 'столу', 'столик', 'стул', 'столе', 'диван', 'поднос', 'столом', 'кухонный']
# ['король', 'принц', 'герцог', 'короля', 'генрих', 'людовик', 'монарх', 'величество', 'королю', 'император']
# ['король', 'королева', 'принцесса', 'короля', 'изабелла', 'королю', 'герцогиня', 'величество', 'людовик', 'королева-мать']

# %% [markdown]
# ## Посмотрим, как работает токенизатор:

# %%
text = df.iloc[10, 1]
print(text)
list(tokenize(text))[:20]
# Out:
# Добрый день, уважаемые пользователи банковских услуг. Хочу предупредить что в данном банке не существуют единых (стандартов/гостов), сотрудники не квалифицированные на горячей линии, получить интересующую информацию возможно только в отделении банка где открыт счёт компании. Регалии современного века ввиде электронного оборота, банк не поддерживает.  Не компетентность банковских сотрудников приносит существенный урон бизнесу. Всю информацию запрашиваемую у банка, лучше получать в чате, что бы было на руках подтверждение всего деалога.
# [Substring(0, 6, 'Добрый'),
#  Substring(7, 11, 'день'),
#  Substring(11, 12, ','),
#  Substring(13, 22, 'уважаемые'),
#  Substring(23, 35, 'пользователи'),
#  Substring(36, 46, 'банковских'),
#  Substring(47, 52, 'услуг'),
#  Substring(52, 53, '.'),
#  Substring(54, 58, 'Хочу'),
#  Substring(59, 71, 'предупредить'),
#  Substring(72, 75, 'что'),
#  Substring(76, 77, 'в'),
#  Substring(78, 84, 'данном'),
#  Substring(85, 90, 'банке'),
#  Substring(91, 93, 'не'),
#  Substring(94, 104, 'существуют'),
#  Substring(105, 111, 'единых'),
#  Substring(112, 113, '('),
#  Substring(113, 123, 'стандартов'),
#  Substring(123, 124, '/')]

# %% [markdown]
# ## Векторизивывать текст будем просто за счёт суммирования векторов всех слов, которые в него входят. Для классификации будем использвать линейную регрессию.

# %%
df['vector'] = df['text'].map(vectorize_text)
df_train, df_test = train_test_split(df[['text', 'target', 'coloring', 'vector']].copy(), test_size=0.3)
x_train, x_test = np.array(df_train['vector'].to_list()), np.array(df_test['vector'].to_list())
y_train, y_test = df_train['target'], df_test['target']
clf = LogisticRegression(multi_class='ovr', class_weight=(1/df_train['target'].value_counts()).to_dict(), max_iter=10000)
clf.fit(x_train, y_train)
# Out:
# LogisticRegression(class_weight={0: 0.0010834236186348862,
#                                  1: 0.0021551724137931034,
#                                  2: 0.0006693440428380187},
#                    max_iter=10000, multi_class='ovr')

# %% [markdown]
# ## В качестве метрики качества будем использовать ROC AUC

# %%
y_pred_train, y_pred_test = clf.predict_proba(x_train), clf.predict_proba(x_test)
df_train.insert(0, 'predictions', [x.round(3).tolist() for x in y_pred_train])
df_test.insert(0, 'predictions', [x.round(3).tolist() for x in y_pred_test])
df_test['predictions'] = [x.round(3).tolist() for x in y_pred_test]
y_pred_train_label, y_pred_test_label = y_pred_train.argmax(axis=1), y_pred_test.argmax(axis=1)
print(multiclass_roc_auc(y_train, y_pred_train))
print(multiclass_roc_auc(y_test, y_pred_test))
# Out:
# 0.9209627708890018
# 0.83775178053805

# %% [markdown]
# ## Confusion матрица

# %%
confusion = pd.DataFrame({'true': y_test, 'pred': y_pred_test_label}).groupby(['true', 'pred']).size() \
    .reset_index(name='fraction').pivot(index='true', columns='pred', values='fraction') \
    .reindex(index=set(sentiment_mapping.values()), columns=set(sentiment_mapping.values())).fillna(0)
confusion /= confusion.sum().sum()
print(confusion)
# Out:
# pred         0         1         2
# true
# 0     0.185425  0.116599  0.026721
# 1     0.076923  0.066397  0.021053
# 2     0.018623  0.025101  0.463158

# %%
print(y_pred_train)
print(y_pred_test)
# Out:
# [[0.05414756 0.19533838 0.75051407]
#  [0.0607772  0.27835546 0.66086735]
#  [0.05957492 0.19452695 0.74589814]
#  ...
#  [0.06638004 0.11507028 0.81854967]
#  [0.09610419 0.15371908 0.75017673]
#  [0.12029712 0.1589067  0.72079617]]
# [[0.01421873 0.370303   0.61547828]
#  [0.02231691 0.07662563 0.90105746]
#  [0.15965322 0.83877105 0.00157573]
#  ...
#  [0.37125496 0.32751086 0.30123419]
#  [0.03961636 0.06774311 0.89264052]
#  [0.55481667 0.34998675 0.09519658]]

# %% [markdown]
# ##  Посмотрим не те тексты, которые были наиболее неправильно классифицированны

# %%
print_most_incorrect(df_train)
print('\n\n\n------------------------------------------------------------------------------------------\n\n\n')
print_most_incorrect(df_test)
# Out:
# ('Я являюсь зарплатным клиентом и до этого приходили смс уведомления о том что '
#  'мне одобрили кредит на 500 000+. пришел в банк, вежливая девушка Анастасия '
#  'сказала ,что да, есть одобернная сумма. Стали оформлять кредит, сумма нужна '
#  'была меньше 130 000 рублей. Месячный доход 65 тыс. руб. (без вычета). '
#  'Девушка сказала что придется подождать до понедельника, и смогу получить '
#  'кредит. В понедельник, 28 сентября прихожу в банк, жду 20 минут очереди и '
#  'мне говорят что Анастасия заболела и сама мне позвонит. В этот день мне '
#  'кто-то звонит и говорит что все ок - могу забирать. Прихожу в офис и говорят '
#  'что Анастасии нет и что не понятно вообще без нее и что заявка на '
#  'рассмотрении. Больше звонков не было. Октября Позвонил в ВТБ, оператор '
#  'сказал что кредит одобрен и что я могу его получить. Пришел в Банк и мне '
#  'заявляют "Кредит одобрен технически, но не нашим руководством, я оставлю '
#  'комментарий Анастасии (которая куда то пропала) и она вам позвонит завтра" '
#  'Звонка от Насти нет второй день. Я вот честно не пойму, что такое вообще? '
#  'Обещают одно - по факту другое. Каким еще руководством может быть одобрен '
#  'кредит. если оператор заявляет что он одобрен? Зачем заявлять что его '
#  'выдадут быстро? Я бы уже давно оформил ту же сумму, под те же проценты в '
#  'другом банке. Повелся на то что я выступаю в роли зарплатного клиента. Очень '
#  'приятно что нарушили все планы. Сорвали отпуск - спасибо огромное! Прошу '
#  'разъяснений по поводу этой ситуации. Почему так долго? Почему никакого '
#  'информирования нельзя получить от офиса на домодедовской. С Уважением, '
#  'Першин Никита Ильич.')
# target                           2
# coloring                      good
# predictions    [0.373, 0.626, 0.0]
# Name: 2640, dtype: object
#
# ('Здравствуйте! В декабре 2019 г. в указанном банке взял потребительский '
#  'кредит. Оплата кредита осуществляется на карту через банкоматы банка была '
#  'проведена вовремя, без задержек. В городе обслуживания, в котором находится '
#  'ближайший банкомат, нет офиса банка. В феврале 2020 г., когда пришел срок '
#  'оплаты ежемесячного платежа через банкомат в г. Сергиев Посад, деньги были '
#  'заложены в банкомат, но на счет не зачислены по причине поломки банкомата. В '
#  'банк мною было подано заявление по факту поломки банкомата и зачисления '
#  'денег по платежу на счет. Инкассация банкомата проводилась около месяца. За '
#  'это время банк начислил пени за неуплату кредита. В офисе банка в г. Мытищи, '
#  'где было написано заявление, мне не было предоставлено ни номера заявления, '
#  'ни номера телефона для связи с ними. Хотя я запрашивал эту информацию. В '
#  'справочной службе номер заявления не могут найти до сих пор. В итоге деньги '
#  'по основному долгу нашлись через месяц. Пени никто не отменил. Службы банка '
#  'так и не разобрались, по чьей вине мое заявление не зарегистрировалось и '
#  'никак не отобразилось. В итоге крайним оказался я. Мне пришлось платить пени '
#  'за неустойку ПО ВИНЕ БАНКА. Сумма конечно не большая, но сам факт такой '
#  'работы с клиентами достаточно неприятен. До сих пор мое заявление не найдено '
#  'и пени банком мне не возвращены. Концов теперь не найдешь. Поэтому обращаюсь '
#  'ко всем: если у вас есть возможность взять кредит в другом банке, то '
#  'обходите Газпромбанк стороной. Так как если ваши деньги "проглотит" '
#  'банкомат, вы их будете месяц потом искать. Офисы есть не во всех городах, '
#  'даже Подмосковья, не говоря уже о регионах. Оценка 2 балла. НЕ РЕКОМЕНДУЮ '
#  'ЭТОТ БАНК!!!!')
# target                           2
# coloring                      good
# predictions    [0.354, 0.646, 0.0]
# Name: 2494, dtype: object
#
# ('Добрый день! Решился на написание отзыва после двухнедельного отфутболивания '
#  'сотрудниками банка. Некомпетентность сотрудников call-центра и офисов банка '
#  'просто не знает границ.  Начну история сначала: Брали ипотечный кредит в ЦИК '
#  '"Смоленский" офис ВТБ в Москве. Сразу поясню: Квартира находится в Москве, а '
#  'сами мы проживаем в Белгороде. Квартира еще строится. Брали ее по ДДУ.</li> '
#  'Досрочно осуществили полное погашение ипотечного кредита через год и тут все '
#  'началось...</li> После погашения ипотечного кредита решили поднять вопрос о '
#  'снятии обременения с квартиры. Ехать в Мск для снятия обременения не '
#  'хотелось, так как в других банках все снимают автоматически и удаленно (без '
#  'участия клиента), например, в Сбербанке, то была мысль, что и тут делается '
#  'все также.</li> Позвонили в call-центр банка и пообщались с двумя '
#  'операторами, которые изначально переадресовывали вопрос друг на друга, а '
#  'потом сказали, что оставят заявку в спец. отделе по ипотеке и нам '
#  'перезвонят. Прошло 3 дня. Нам перезвонил специалист по ипотеке и сказал, '
#  'чтобы снять обременение на эту квартиру не нужно ехать в Мск, а достаточно '
#  'просто придти в Белгородский офис на Ватутина 8а и оставить соответствующую '
#  'заявку.</li> Позвонили опять в call-центр ВТБ. Девушка переключила на '
#  'специалиста (парень), который сказал, что для снятия обременения нам нужно '
#  'заказать закладную. ЗАКЛАДНУЮ КАРЛ!!! На непостроенную и не сданную в '
#  'эксплуатацию квартиру!!! (Сотрудники банка ВТБ - вы в своем уме???). Ну '
#  'ладно. Поспрашивая его о том, что разве так можно, мы услышали '
#  'утвердительный ответ, что он сейчас оформит заявку на выдачу нам закладной и '
#  'через месяц, вместе с доверенностью на сотрудника белгородского ВТБ '
#  '(доверенность представлять банк в территориальном МФЦ для снятия '
#  'обременения) она придет в Белгород и нам позвонят. На этом наш разговор '
#  'закончился.</li> Еще через 2 дня нам позвонили из ВТБ (отдел ипотеки в Мск) '
#  'и спросил - "А что ваш дом уже ввели в эксплуатацию??? Какая нафиг '
#  'закладная? Как я вам ее оформлю???" На что я ответил, что это '
#  'некомпетентность ваших же сотрудников банка. В итоге наш разговор закончился '
#  'тем, что она сказала, что удалит эту глупую заявку и никакую закладную '
#  'оформлять не будет.</li> Так незаметно прошла неделя.</li> Опять позвонили в '
#  'call-центр, где связали с Белгородским отделением на ул. Проспект Ватутина '
#  'д.8а, где нам сказали, что нужно приехать к ним и они все решат на '
#  'месте.</li> Приехали в офис банка в Белгороде. Прошли в 19 кабинет. '
#  'Рассказали историю с самого начала. Специалисты сказали - есть такая '
#  'возможность снять обременение удаленно, отсканировали ДДУ, отправили в МСК '
#  'офис и сказали ждать звонка.</li> Прошло 10 дней. Звонков не поступало. '
#  'Позвонил в call-центр банка ВТБ. Там ответили, что заявки на снятие '
#  'обременения не поступало.</li> Позвонил в белгородский офис ВТБ. Менеджер из '
#  'белгородского офиса ответила, что пришло ответное письмо из Москвы, что для '
#  'снятия обременения нужно согласовать время с сотрудниками московского '
#  'филиала для совместного визита в Московский МФЦ, чтобы снять обременение и '
#  'дала мне 3 номера телефона, которые были указаны в этом письме:</li> '
#  'доб.413049). По данным номерам телефона никто не берет трубку. Супер '
#  'обслуживание))) Я до сих пор не знаю, что БЛ... мне делать))). Если бы я не '
#  'платил по кредиту, то уже на третий день просрочки по платежу вы бы стояли у '
#  'дверей моей квартиры и оборвали мне все телефоны, звоня ежеминутно. А когда '
#  'заплатил, так теперь не знаете как отморозиться и не решить вопрос. Все '
#  'будущие кредиты и ипотеки будут не в вашем банке. Спасибо за такой сервис.')
# target                           2
# coloring                      good
# predictions    [0.396, 0.604, 0.0]
# Name: 2520, dtype: object
#
# ('Пользовался картами банка, так как в институте оформляли для зачисления '
#  'стипендии. Когда пользовался услугами банка всё было относительно хорошо, '
#  'банкоматы в крупных ТЦ есть, смс-информирование работало исправно, '
#  'обращаться в офисы банка приходилось только после перевыпуска карт в связи с '
#  'истекшим сроком действия, да и то если в институте не смог получить. В '
#  'общем, всё устраивало. В какой-то момент обучения перестал получать '
#  'стипендию, но карту хранил до конца обучения. После окончания учебы карту '
#  'выкинул так как срок действия карты уже истёк. Про банк, как и про карту на '
#  'этом забыл. Прошло чуть больше года, и при переоформлении различных '
#  'документов на сайте налоговой обнаружил что счета (то есть уже не один счет, '
#  'а два) до сих открыты... Справедливости ради обнаружил и незакрытый счет в '
#  'другом банке. Обратился в оба банка для закрытия счетов, так как они больше '
#  'не нужны. В другом банке счет ЗАКРЫЛСЯ в тот же день (информация с сайта '
#  'налоговой). В ГПБ же счета не закрыли даже по истечении двух месяцев. '
#  '15.10.2021 г. позвонил по телефону <em>0701, сказали что возможно ещё сроки '
#  'рассмотрения не вышли. Нашёл этот пункт в заявлении о прекращении срока '
#  'действия банковской карты и закрытии счета карты: написано 10</em>/45* дней, '
#  'посчитал сколько времени прошло от дня обращения, даже если считать только '
#  'рабочие дни, то 45 дней уже прошли. Сотрудник службы поддержки предложил '
#  'создать обращение, сказав что до 22.10.2021 должны проинформировать о '
#  'результатах рассмотрения данного обращения. 21.10.2021 звоню по тому же '
#  'номеру, говорят что счета до сих пор не закрыты! Замечательно. номер '
#  'обращения  СД03289571 от 15.10.2021.  Не понимаю, почему я должен бегать в '
#  'отделения банка, а затем проверять результаты работы банка, звонить, '
#  'оставлять обращения и снова ждать? Почему должен тратить время на это? '
#  'Почему нельзя просто закрыть счет после того как срок действия карты истек и '
#  'никаких действия по счету не происходит более года? Как результат '
#  'дополнительно написал жалобу на сайте ЦБ. Из "+": пока пользуешься услугами '
#  'банка, всё хорошо. служба тех.поддержки отвечает быстро, более-менее '
#  'пытаются разобраться в вопросе и предложить какие-то решения. МИНУСЫ: '
#  'какая-то полная безответственность. сами закрыть счета не могут, тратишь '
#  'своё время на визит в офис, потом как за маленькими детьми всё нужно '
#  'перепроверять, опять звонить им и выяснять что почему и как, потом снова '
#  'звонить... и так по кругу, вот уже 2.5 месяца счета не могут закрыть( так '
#  'никто и не позвонил и никаких смс не пришло с результатом рассмотрения '
#  'обращения снова звонил им по *0701: заявка находится на рассмотрении, '
#  '"жалобу на сроки" оператор составила сама. позвонили из отделения банка, в '
#  'котором писал заявления на закрытие счетов, уточнили смогу ли явиться к ним '
#  'в отделение для того чтобы написать новое заявление. Согласился. Посетил '
#  'данное отделение, и написал новое заявление с просьбой закрыть счета в '
#  'кратчайшие сроки (копии предыдущих заявлений так же приложил), обещали '
#  'связаться как только счета будут закрыты (сказали что ориентировочные сроки '
#  '- 7 дней), принесли свои извинения за доставленные неудобства, теперь жду '
#  'закрытия. позвонили из д/о и сообщили что счета закрыты. Спасибо!')
# target                           2
# coloring                      good
# predictions    [0.556, 0.444, 0.0]
# Name: 2368, dtype: object
#
# ('Пришла в 17.15 -ведется запись, мой номер 76, к этому времени прошло 35 '
#  'человек, шансов до 20.00 почти нет. Ладно, приду в субботу пораньше. Сегодня '
#  'пришла в 9.10 утра, у дверей толпа человек 12. Пустили в офис ровно в 10.00 '
#  'Меня удивило, что в субботу (короткий день,работают до 16.00) работали все 5 '
#  'окон, никаких скандалов из-за очереди, я была где-то 15-я и оформила все до '
#  '11 утра. Никаких раздражительных сотрудников, девочки работали оперативно и '
#  'вежливо. Состояние авторов предыдущих негативных отзывов понять могу. Сама '
#  'была не раз в такой ситуации.Но ведь иногда мы же сами такую ситуацию '
#  'создаем. Сейчас в очереди в основном пенсионеры сами нагнетают нервозность, '
#  'слухи пускают. А ведь в банке работают обычные люди, такие же как наши дети '
#  'или близкие. Не все могут сдержать раздражение или агрессию при таком '
#  'наплыве людей. Поймите меня правильно, я ни в коем случае не оправдываю '
#  'грубость и хамство, просто иногда надо встать на место другого. Сейчас сама '
#  'не могу получить досрочно закрытый вклад в другом банке, тоже на грани '
#  'срыва, но подумала что тратить свое здоровье из-за этих денег не стоит. '
#  'Поэтому сегодняшнее посещение отделения на Садовнической ул. оставило '
#  'хорошее впечатление.')
# target                          2
# coloring                     good
# predictions    [0.469, 0.53, 0.0]
# Name: 2680, dtype: object
#
# ('любой вопрос вам придется решать в офисе, просидев в очереди раз за разом, '
#  'так как мобильное приложение абсолютно не функционально,а по телефону вам '
#  'просто посочувствуют и предложат постоять в той самой потной очереди. Теперь '
#  'о ситуации. Имею два потребительских кредита. 07.06.2019 года явился в офис '
#  'в г.СПб в тот,что у м.Пр.Большевиков,написал два заявления о досрочном '
#  'погашении и сказал девушке,чтобы посчитала сумму остатка с учетом процентов( '
#  'по телефону этого сделать не смогли, 20 мин я слушал музыку,после чего мне '
#  'сказали,что у них не прогружается программа,так как меняют программное '
#  'обеспечение lol). После этого я сообщил,что у меня наличные на руках и мне '
#  'нужно положить деньги на счет,чтобы было все красиво. Девушка оформила '
#  'платежку для внесения на счет карты и я внес всю сумму по двум кредитам на '
#  'этот счет. После этого я уточнил,все ли будет хорошо, так как в одном '
#  'заявлении было указано,что списание с карты,а в другом с кредитного счета. '
#  'Она замешкалась, позвала старшего сотрудника и та после копаний в '
#  'компьютере,выдала мне,что все окей, при недостатке денег на кредитном счете, '
#  'банк будет «черпать» там,где они есть. Я напрягся,но все же ушел. Настало '
#  '08.06.19 -дата досрочного полного погашения кредитов и ничего не происходило '
#  'часов до 16. Я позвонил в тех.поддержку,где попросил уточнить,имеются ли в '
#  'базе мои заявления. Ответ меня порадовал: да, заявления имеются,но погашение '
#  'одного кредита будет со счета карты,а второго с кредитного счета... Уау,как '
#  'прекрасно. Я говорю,можно ли привязать сейчас карту к тому кредиту,чтобы '
#  'сегодня все списалось. «нет» сказали мне, «только через отделение»(на '
#  'минуточку суббота перевалила за 16:00,а я на пляжике чилю). Говорю,окей, '
#  'может тогда переведем деньги с карты на кредитный счет!? Ответ:да, но '
#  'перевод прогрузится в след.рабочий день. Сообщение о некомпетентности '
#  'сотрудников,что они ввели меня в заблуждение, действий не возымело. '
#  'Разозлившись, попросил переключить на самого старшего сотрудника горячей '
#  'линии, услышав тоже самое,она пообещала позвонить в отделение. Но от туда '
#  'мне никто не перезвонил. Зашел в чудо-приложение, попробовал перевести с '
#  'карты на кредитный счет, но этой функции в разделе карты и меню счета просто '
#  'не оказалось. Вечером попробовал через банкомат снять деньги с карты - отказ '
#  'операции. Итог: не компетентность сотрудников,которые только задают '
#  'вопросы,а не решают их, не современность системы клиентского обслуживания '
#  'приводит меня к тому, что я вынужден в понедельник вновь посетить '
#  'отделение,потерять час минимум, подать заявление на привязку карты к '
#  'кредиту, подать заявление на погашение кредита и что самое главное пополнить '
#  'счет на сумму начисленных за три дня процентов по кредиту. Иных способов я '
#  'не вижу. Крайне не советую данный банк,если вы дорожите своим временем и '
#  'нервами.')
# target                             2
# coloring                        good
# predictions    [0.365, 0.634, 0.001]
# Name: 2545, dtype: object
#
# ('года, вносил 10000 рублей через банкомат № 467696, расположенный в отделении '
#  'Газпромбанка по ул.Савушкина 25, в городе Астрахань. Банкомат деньги взял, '
#  'но зачисленными на счет они не стали. Банкомат выдал чек в котором было '
#  'отображено что внесено 10000 рублей и так же еще одна запись, что транзакция '
#  'не может быть выполнена. Тут же обратился с заявлением о неуспешной операции '
#  'в банкомате в это отделение  Газпромбанка, где приложил копию чека к '
#  'заявлению. Специалист банка объяснила, что  рассмотр проишествия проходит в '
#  'течении 30 дней. Так же, в этот день я позвонил на горячую линию '
#  'Газпромбанка, где приняв мое заявление, сказали что, так же будет рассмотр '
#  'заявления и возрат денег в течении 30 дней. Так же мне сказали , что этот '
#  'банкомат не исправен  и его должны ремонтировать, но информационных табличек '
#  'об этом на банкомате не было, что выглядит очень странно, получается '
#  'сотрудники банка зная об неисправности, не приняли мер об выводе банкомата '
#  'из эксплуатации, что бы клиенты банка не оказывались в подобной  ситуации. '
#  'По истечении более 30 дней ( 11 августа 2020 года ) , деньги мне так и не '
#  'были зачислены на счет. После очередного звонка на горячую линию, получил '
#  'ответ специалиста, об том, что сведений об рассмотрении моего дела он не '
#  'видит в базе и что он отправил снова мое обращение  специалистам, которые '
#  'непосредственно этим занимаются, и что это новое обращение будет '
#  'рассматриваться в течении 30 дней!!! Как такое возможно!!! Такие проблемы, '
#  'должны оперативно решаться! Деньги взяли и все, а они мне срочно нужны!')
# target                             2
# coloring                        good
# predictions    [0.561, 0.438, 0.001]
# Name: 2467, dtype: object
#
# ('Дозвониться по горячей линии банка вообще не возможно. Заказали обратный '
#  'звонок и он был назначен (внимание!) на 00:00. Прям 5 балов! Дальше больше. '
#  'Звонок был. На проводе со стороны банка Ольга С-ва (или фамилия созвучная '
#  'этой). Объясняем ситуацию, что кредит был взят в Допофисе Рязанский проспект '
#  'в г. Москва под ипотеку земельного участка. Что за это время он закрылся, но '
#  'наши обязательства по возврату кредита выполнены полностью и мы хотим снять '
#  'обременение. Что для этого нужно, чтобы сотрудник банка приехал с нами в '
#  'отделение мфц по месту нахождения земучастка, или без нас. Но только '
#  'сотрудник банка сможет его снять.<br/> Сотрудница на проводе говорит, чтобы '
#  'подождали и она проверит этот доп офис. Ждём. Отвечает: «А вы знаете, а у '
#  'нас нет офиса на Рязанском проспекте» Жесть! «Девушка, вы нас не слышите? Мы '
#  'просим вас дать ответ где сейчас наши документы после закрытия офиса на '
#  'Рязанском проспекте?» «Оставайтесь на проводе...» и опять ждём. Ответ '
#  'сотрудника: «У нас нет информации, что офис на Рязанском проспекте был. '
#  'Рекомендую вам позвонить в офис  банка в рабочее время». Сказать, что '
#  'неквалифицированный, неосведомлённый и некомпетентный персонал, это ничего '
#  'не сказать... Зачем делать вообще тогда «Горячую линию»?!')
# target                             2
# coloring                        good
# predictions    [0.797, 0.202, 0.001]
# Name: 2564, dtype: object
#
# ('С номеров совкомбанка звонят мошенники,  и предсавляются службой '
#  'безопасности банка,  звонили с разных номеров,  но все принадлежат '
#  'совкомбанку,  они знают всю информацию о клиенте этого банка,  номер счёта,  '
#  'номер договора,  последние операции по карте за несколько месяцев,  '
#  'паспортные данные,  и т.д. Затем они выпытывают коды пришедшие в смс,  якобы '
#  'для открытия безопасного счёта,  чтобы обезопасить от мошенников. Как '
#  'посторонние мошенники могут звонить с номеров совкомбанка,  и знать всю '
#  'информацию о клиентах??? Таких случаев уже сотни,  но отрудники в офисах '
#  'говорят что виноват только клиент,  потому что называл эти коды мошенникам, '
#  'с одной стороны они правы,  но  вот и возникает вопрос,  или в этом банке '
#  'завелись крысы,  или сам банк решил нажиться за счёт клиентова а всё свалить '
#  'на мошенников. Где сужба безопасности этого банка?  Как личные данные '
#  'поступают мошенникам? И почему сотрудники банка не могут дать внятных '
#  'ответов,  ни чего не могут решить,  а только говорят о том,  что они '
#  'БЕССИЛЬНЫ против этих мошенников... А если они бессильны,  тогда может ФСБ,  '
#  'Следственный комитет,  и другие правоохранительные органы должны разобраться '
#  'с этим совкомбанком,  и обязать этот банк компенсировать убытки пострадавших '
#  'клиентов!')
# target                             2
# coloring                        good
# predictions    [0.897, 0.102, 0.001]
# Name: 2555, dtype: object
#
# ('Здравствуйте!!! Не связывайтесь с Совкомбанком!!! Никогда! В январе этого '
#  'года решил оформить автокредит, сумма кредитования была 320 т.р. При '
#  'оформлении договора, ни слова не было о страховке, о карте золотой ключ! При '
#  'подписании договора, я увидел, что сумма вместе с % составляла 650 т.р.! В '
#  'неё вошла страховка 60 т.р., обслуживание "бесплатной карты" 4999 т.р. и смс '
#  '- оповещение порядка 9000 р. Карту и смс-информирования с трудом отключил, '
#  'через 3 дня после оформления договора поехал в отделение банка для того, '
#  'чтобы отказаться от страховки. Сотрудник банка стал меня пугать повышением % '
#  'ставки и добавил - погасите досрочно кредит, Вам вернут часть страховой '
#  'суммы за неиспользованный срок! Погасил кредит досрочно, за 6 месяцев, '
#  'сделал запрос на возврат денег, пришёл отказ! Так же писал официальное '
#  'заявление в отделении банка, где сотрудник на мой вопрос - вернут ли, '
#  'ответила - да, конечно! СОФКОМ банк просто присваивает Ваши деньги! При '
#  'досрочном погашении смысла нет в страховке, при страховом случае сумма '
#  'выплаты равна сумме долга! А если долга нет, то и выплат нет! 100 раз '
#  'подумайте, перед тем, как связаться с этим банком! Уж лучше старый, '
#  'проверенный "Сбербанк"!!! Там и ставка меньше по кредиту, и знакомый вернул '
#  'часть страховки при досрочном погашении!!!')
# target                             2
# coloring                        good
# predictions    [0.233, 0.766, 0.001]
# Name: 2472, dtype: object
#
#
#
#
# ------------------------------------------------------------------------------------------
#
#
#
# ('Здравствуйте! <strong>Я оформил мультикарту</strong> ВТБ 04.07.2018 для '
#  'накопления миль на путешествия! Спустя 9 дней (13.07.201использования карты '
#  'с меня списали незначительную сумму (121 руб.). Я <strong>решил уточнить за '
#  'что были списаны деньги</strong> и 14.07.2018, около 10-10.15 утра обратился '
#  'к консультанту в онлайн-чат (в приложении ВТБ). Консультант Екатерина, '
#  'проверив информацию, сказала, что деньги списаны 13.07.2018 в магазине '
#  '"Дикси" . Я ответил,что не был в этом магазине. <strong>Сотрудник банка без '
#  'предупреждения блокирует мою карту.</strong> Я звоню на горячую линию ВТБ, '
#  'где мне говорят, что оплата была не 13.07.2018, как сказал сотрудник в чате, '
#  'а 11.07.2018 около 22:00. После указания правильной даты  я вспомнил об этой '
#  'оплате.  Т. е. <strong>сотрудник банка</strong>, <strong>неправильно указав '
#  'дату списания средств, ввела меня в заблуждение.</strong> При этом моя '
#  '<strong>карта без предупреждения была заблокирована</strong>, <strong>без '
#  'возможности разблокировки.</strong> Оператор горячей линии сказал, что  мили '
#  'за средства потраченные на заблокированной карте начислены не будут, '
#  'вследствие чего <strong>я понес убытки</strong> в виде сгоревших миль за '
#  'покупки с этой карты за этот месяц.  Фамилию сотрудника, заблокировшего мою '
#  'карту, назвать отказались. В банках, которые работают для людей (не пишу '
#  'название,  чтоб это не казалось рекламой), в таких ситуациях карта '
#  'блокируется на сутки, до выяснения причин. После разбирательства и если '
#  'клиент подтверждает оплату карта разблокируется. Но, видимо, <strong>банк '
#  'для людей - это не про ВТБ.</strong> Я требую разблокировать мою карту и '
#  'вернуть мне мили за покупки по моей карте!')
# target                           2
# coloring                      good
# predictions    [0.636, 0.363, 0.0]
# Name: 2580, dtype: object
#
# ('Взяли ипотеку в псб год назад и уже пожалели тысячу раз! Один раз вынуждены '
#  'были просрочить дату платежа по ипотеке на неделю, оплатили с пени и '
#  'успокоились. Но стали бесконечно названивать сотрудники из отдела '
#  'задолженности мне, мужу, родителям каждый день по 5 раз! Говорят, у вас '
#  'просрочка и начинают отвратительно давить на жалость фразами «вы же '
#  'понимаете, что на деньги, которые вы оплачиваете пени, вы могли бы что-то '
#  'купить для семьи»!! Объясняем, что просрочку погасили, чтобы проверили '
#  'данные, говорят «ничего не видим». Ходили в отделение банка, там говорят '
#  '«да, не видим платежа». Написали заявление на проверку платежей, ждали '
#  'полторы недели вместо обещанных 3-х дней, когда в головном офисе проверят '
#  'платежи. Наконец-то сказали, что да, почему-то был сбой и не прошли два '
#  'платежа за март и июль (разбирались в конце июля). Мы спросили, точно ли '
#  'сейчас проблем нет и не будут ли звонить из отдела задолженностей, сказали, '
#  'что да, все хорошо. Прошло 2 дня, опять звонки, опять они ничего не видят. '
#  'Говорю, что звоните а отделение, наладьте связь между отделами, проблема у '
#  'вас, отвечают, что проблема у нас, а не у них в банке. Опять пошли в банк '
#  'разбираться, на этот раз старший менеджер звонил напрямую в отдел '
#  'задолженностей, долго сверяли данные и наконец нашли проблему. Мы выдохнули. '
#  'Прошла неделя, опять звонят и говорят, что просрочка!!! Они даже в своем '
#  'отделе разобраться не могут в этом головном офисе!! Говорят опят: идите а '
#  'банк, а толку: там говорят, что все хорошо, а головной офис опять «ничего не '
#  'видит»! Отвратительное обслуживание!!! Нет сил уже с ними говорить и '
#  'разбираться!')
# target                           2
# coloring                      good
# predictions    [0.455, 0.545, 0.0]
# Name: 2539, dtype: object
#
# ('Обратился в отделение банка в городе Красноярск, для досрочного погашения '
#  'кредита. Попросил что бы мне сказали сумму задолженности на данный момент и '
#  'хотел написать заявление на досрочное гашение. И вот тут то началось.... '
#  'Оказывается сейчас в кассах банка не принимают оплату мене 500 000 рублей '
#  '(интересно мне сколько в день человек проходит через кассу при таком '
#  'условии, нужно ради интереса посчитать сколько у нас миллионеров в день в '
#  'кассу банка приходит, ну так чисто для себя информацией владеть. А мы значит '
#  'челядь неприглядная раз у нас нет таких платежей и сумм нет, то вам не в '
#  'кассу а в банкомат). Хорошо, мне не особо принципиально, в кассу или в '
#  'банкомат внести сумму (отношение банков к людям давно всем известно). Но '
#  'далее мне сказали что заявление на закрытие кредита и досрочное гашение '
#  'специалисты тоже не делают, это нужно делать через личный кабинет (сейчас '
#  'сделали так и никак иначе). Личного Кабинета у меня конечно же не было, да и '
#  'зачем он мне, меня и без него всё устраивало, но тут как оказалось нужно '
#  'через него создать заявление, хорошо согласился и на это - создали мне '
#  'личный кабинет и я говорю а если у меня ни телефона ни компьютера нет как '
#  'мне быть (ведь однозначно есть люди у которых нет компа и телефона с выходом '
#  'в интернет)? Мне сказали что снизу есть специалист и компьютер, там помогут '
#  'и всё сделают. Только вот что бы создать Личный Кабинет который нужен Банку '
#  'а не мне, нужно было подписать кипу каких-то бумаг где мне открывали '
#  'какой-то непонятный счёт, специалист сказала что это формальность и счёт '
#  'сразу после открытия автоматом закрывается, только об открытии речь в '
#  'бумагах шла а о закрытии этого счёта ни слова. Да и вообще у меня буря '
#  'эмоций и негодования, почему я должен подписывать кучу каких-то бумаг для '
#  'того что бы мне просто открыли личный кабинет на их сайте который я ПРОШУ '
#  'ЗАМЕТИТЬ даже и НЕ Просил, это прерогатива банка. Я в очередной раз '
#  'вдохнул-выдохнул и пошёл вниз к специалисту, и что бы вы думали....  на этом '
#  'всё не закончилось. Специалист конечно же помочь не отказался, но мы не '
#  'смогли войти в личный кабинет, так как зависла система и я даже уже не '
#  'удивился а просто рассмеялся. Короче ИТОГ и вывод такой: Я пришёл в банк с '
#  'хорошим настроением закрыть кредит, провёл там 2,5 часа и ушёл оттуда с '
#  'плохим настроением так ничего и не закрыв. Всё что я смог сделать это '
#  'закинуть на карточку денег (через которую платил кредит всё время), но для '
#  'этого с самого начала не требовалось 2,5 часа. Хочу сказать что банк '
#  'Тинькофф в этом плане рулит, у них нет офисных помещений на земле, всё '
#  'функционирует он-лайн. И вот им можно сказать своим клиентам, зайдите в '
#  'Личный Кабинет... А тут получается есть офисы, есть "громкое" имя банка, '
#  'есть специалисты а толку от этого 0 (ноль). Ни кому не посоветую Банк ВТБ.')
# target                           2
# coloring                      good
# predictions    [0.444, 0.556, 0.0]
# Name: 2571, dtype: object
#
# ('Оговорюсь сразу: из всех банков - ВТБ самый крутой. Уж что касается '
#  'потребкредитования - точно.</strong> Но меня потрясло до слез, что меня, '
#  'клиента с многогодовалым стажем (зарплатного клиента), активно пользующегося '
#  'кредитами, просто опустили из-за задолженности в 53 рубля. Причем, об этой '
#  'задолженности я узнала только спустя шесть дней. Из письма, которое пришло '
#  'на почту.  Я тут же внесла необходимую сумму и позвонила в отдел по работе с '
#  'должниками. Пыталась выяснить, почему только спустя шесть дней? Почему на '
#  'почту? Где смс? Почему не увидела просрочку в личном кабинете? Оператор мне '
#  'ответила, что мне пытались звонить, но не дозвонились. И назвала номер '
#  'телефона, который я не указывала при оформлении кредитного продукта, '
#  'которого у меня уже давно нет. Вот это "мы пытались, но не смогли" меня '
#  'расстроило больше всего. Мой любимый банк, ну как так?!?!?! Как из-за 53 '
#  'рублей у меня теперь испорчена кредитная истори? Жалобу я оставила по '
#  'телефону горячей линии. Спойлер: только последний сотрудник, молодой человек '
#  '(СПАСИБО ЕМУ) общался достойно и корректно, как и подобает при общении с '
#  'клиентами и принял жалобу. А три специалиста до, с которыми я говорила, '
#  'просто отняли мое время. Особый шок -  сотрудники из отдела по просроченной '
#  'задолженности. Господа, что за тон? К чему мне ваши комментарии в мой адрес '
#  'и фырканье?  Алле, эти 53 рубля я пропустила не потому, что не хотела '
#  'вносить, а потому, что просто не заметила. И я была свято уверена, что, '
#  'ежели что, банк со мной свяжется, напомнит, если возникнут какие-нибудь '
#  'проблемы. Я идеальный заемщик, я всячески стараюсь ничего не забыть, не '
#  'пропустить, чтобы это не отразилось на моей кредитной истории. Но сегодня, '
#  'из-за 53 рублей, из-за того, что со мной связались только спустя неделю, '
#  'из-за неверного телефонного номера, в моей кредитной истории темное пятно. '
#  'ПРОСРОЧКА 6 ДНЕЙ. И дамы из отдела по работе с должниками мне сказали, что '
#  '"что я сама виновата, и что надо самой контролировать погашение, а не '
#  'надеяться на помощь банка". Тут я соглашусь лишь с первой частью. Виновата, '
#  'не досмотрела. Но я же клиент, мне иногда нужна помощь, когда я где-то '
#  'что-то упускаю. И да, это МОЯ кредитная история, и она теперь у МЕНЯ '
#  'испорчена, поэтому я эмоционирую. Но сотрудникам, разговаривать "через '
#  'губу", по меньшей мере, не позволительно. Спасибо.')
# target                         2
# coloring                    good
# predictions    [0.62, 0.38, 0.0]
# Name: 2425, dtype: object
#
# ('Почему в будний день утром работает только одна касса из трех и только один '
#  'операционист?Одно дело выходной,это понятно,но в будний почему так?Девочки '
#  'вдвоем не успевают ни качественно обслуживать,ни вызывать клиентов по '
#  'вкладам,кого то вызвали,кто-то так проходит.Была сознана очередь(причем не '
#  'маленькая) из тех ,кому надо было просто оплатить квитанции и тех,кто делает '
#  'вклад.Пропустив перед собой несколько человек,я прошла в кассу.Тут же,следом '
#  'за мной заходит мужчина,простите,не малых размеров,начинает меня '
#  'оскорблять,орать,просить выйти.На мои доводы не реагировал,а в завершении '
#  'еще и толкнул. При этом ни кассир,ни охранник,никто не среагировал.Почему '
#  'посторонние люди проходят вслед за мной в кассу? Получается,что ваш банк не '
#  'безопасен для клиентов?А в следующий раз не просто толкнут, а еще и нож '
#  'вытащат? Выйдя из кассы я прошла к охране и попросила разобраться в '
#  'ситуации. Жаль,что ,как выяснилось,в кассах у вас нет камер(это со слов '
#  'охранника) и нельзя было посмотреть все это безобразие,ведь мужчина стал все '
#  'переиначивать и заявил,что никого он не толкал!Правды добиться не '
#  'получилось,а осадок остался,хотя о вашем банке у меня сложились очень '
#  'хорошие впечатления.Очень жаль,что на месте не было и управляющего банком,а '
#  'работницы,хоть и были предельно вежливы и отзывчивы,что-то лепетали про '
#  'очереди и утренние часы(а когда же должны еще работать ВСЕ КАССЫ,как не в '
#  'утренние часы будних дней и на месте быть управляющий),проблема не '
#  'решилась!.Конечно,хоть вы и ничего не потеряете(не могу сказать,что мой '
#  'вклад очень большой),боюсь,что это был последний раз,когда я буду '
#  'пользоваться услугами вашего банка.')
# target                           2
# coloring                      good
# predictions    [0.511, 0.489, 0.0]
# Name: 2660, dtype: object
#
# ('Я А-ва Анна Александровна,  имею кредит взятый 22.09.2017 года , контракт № '
#  '584327290, в виду сложившихся обстоятельств не смогла выполнять обязательсва '
#  'по кредитному договору, при этом частично погашала задолженость и находилась '
#  'на связи.  26 августа 2019 года по телефонной договоренности с отделом '
#  'просроченной задолженности Промсвязь банка я должна прийти 04 сентября 2019 '
#  'года по адресу: Маршала Чуйкова, 65А, для внесения платежа в размере 20 550 '
#  'рублей для завершения процедуры предложеной мне реструктуризации долга по '
#  'кредитному договору. О чем мне напоминали по СМС что нужно внести платеж '
#  'согласно договоренности. сентября 2019  года я приезала в отделение по '
#  'вышеуказному адресу и обратилась к сотруднику банка с просьбой объяснить что '
#  'нужно сделать. Меня отправили в кассу оплатить сумму по долговечности 20 550 '
#  'рублей, что я сделала и вернулась к сотруднику для получения нового графика '
#  'платежей, который нам сказал получить сотрудник отдела просроченной '
#  'задолженности после совершения оплаты. Сотрудник сообщил нам что новый '
#  'график выдать не может, т.к. договор на реструктуризацию проводят в ручном '
#  'режиме в Москве, что новый график платежей вы увидите в личном кабинете '
#  'после того как в москве проведут договор в исполнение и можно не получать '
#  'его на бумажном носителе. Я возразила и сказала что мне сказали что я его '
#  'должна получить, на что он ответил , что не может его выдать сейчас. Все это '
#  'время по сегодняшний день продолжаются звонки из банка с просьбой погасить '
#  'задолженность и говорят что ни какой реструктуризации у Вас нет. Я '
#  'связывалась с сотрудниками банка сама в понедлеьник 09 сентнября 2019 года, '
#  'кое как удалось добится информации о том,  что мне сказали, реструктуризация '
#  'идет и документы в обработке, были выходные и не успели еще ,чтобы я '
#  'ожидала. сентября 2019 мне позвонили из отдела по задолжености и сказали, с '
#  'сегодняшнего дня со мной работает коллектрское агенство и что все вопросы '
#  'теперь решать с ними, что договор реструктуризации не был сделан из за того '
#  'что мы не подписали новый договор и график платежей. Получается что по вине '
#  'сотрудника вашего банка я не получила договор и сейчас мне звонят из '
#  'коллекторского агентства, хамят и угрожают. сентября я пошла в банк узнать '
#  'что же мне делать и кто виноват в ложившейся ситуации. Меня выслушали, взяли '
#  'мой номер телефона и скзалаи что разберутся. 16 сентября Мне позвонили с '
#  'Волгоградского офиса на Чуйкова 65 А и попросили позвонить по номеру '
#  '+74957771020 и уточнить по решению моего вопроса. Я позвонила в ответ '
#  'услышала хамское отношение и смысл диалога был таков, что я ничего не '
#  'погасила и у меня просрочка , что мое дело передано в Коллекторское агентсво '
#  'и все вопросы решайте с ними, а на счет реструктуризации девушка сказаза ну '
#  'не я же виновата что вы не подписали договор, поэтому ничем не могу помочь  '
#  'решайте все с колекторами.')
# target                           2
# coloring                      good
# predictions    [0.552, 0.448, 0.0]
# Name: 2535, dtype: object
#
# ('По кредитному договору № 61914328653 от 08.05.2015г. внес сумму для '
#  'последовательного и поочередного погашения двух будущих месячных платежей. '
#  'Без моего заявления банк списал эти средства в счет досрочного погашения '
#  'задолженности и в ближайший период вынес мне предупреждение о возникшей '
#  'задолженности с требованием ее погасить и погасить начисленные пени. Мое '
#  'предложение разобраться банк не принял к сведению, обвинив меня в незнании '
#  'заключенного договора, период разбирательства обозначил в 4 недели. Получить '
#  'ответ о возможности мирного урегулирования спора не получалось так как на '
#  'телефонные звонки и компьютерные запросы отвечают сотрудники, либо не совсем '
#  'компетентные, либо не принимающие решения, а приходящие ответы написаны по '
#  'принципу «отстань». Начались звонки и посылка сообщений мне, родственникам и '
#  'коллегам по работе о немедленном погашении «возникшего» долга. Одновременно '
#  'банком были внесены недостоверные сведения в кредитную историю о '
#  'несвоевременных платежах. Учитывая неадекватность поведения банка, кредит '
#  'досрочно погасил. В ходе сложившейся между нашими сторонами ситуации-споре '
#  'со стороны ПАО «СКБ-банк» были: нарушены пункты заключенного кредитного '
#  'договора и неправомерно списаны денежные средства со счета в счет досрочного '
#  'погашения кредита, без написанного мною заявления,</li> нарушены пункты '
#  'заключенного вышеуказанного кредитного договора и не правомерно начислены '
#  'пени, не возвращенные до настоящего времени (01.04.2018г.),</li> нарушена '
#  'статья 5 ФЗ от 03.07.2016 №230-ФЗ «О защите прав и законных интересов '
#  'физических лиц при осуществлении деятельности по возврату просроченной '
#  'задолженности.» в части того что, я письменного разрешения на взаимодействия '
#  'с третьим лицами не давал и в телефонных разговорах с операторами '
#  'департамента по просроченной задолженности СКБ-банка просил вести переговоры '
#  'только со мной.</li> нарушена часть 3 статьи 128.1 УК РФ о распространения '
#  'лицами ложных и недостоверных сведений, которые воспользовались своим '
#  'служебным положением, и нанесли потерю мне репутации (чести и достоинства) '
#  'перед коллегами и подчиненными,</li> внесение недостоверных сведений '
#  'ухудшающую мою кредитную историю.</li>')
# target                             2
# coloring                        good
# predictions    [0.792, 0.208, 0.001]
# Name: 2582, dtype: object
#
# ('Уже как год плачу ипотеку в газпромбанке. У меня в октябре родился 3-й '
#  'ребенок и я решил по госпрограмме дом.рф погасить 450000. Оказалось что я не '
#  'писал заявление на закладную, написали 1 месяц, подали и зарегистрировали '
#  'еще 1 месяц, на данный момент закладную сажают в программу газпромбанка '
#  'больше месяца и до сих пор ничего не сделали. Сотрудники в офисе банка '
#  'говорят что тоже ждут когда доблестные сажатели закладной в газпромбанке это '
#  'сделают. И когда они это сделают никто не знает. По обратной связи ответа '
#  'нет, в коллцентре также ничем не могут помочь.')
# target                             2
# coloring                        good
# predictions    [0.369, 0.629, 0.001]
# Name: 2440, dtype: object
#
# ('Проблема решена. г. - пришла в филиал Росбанк в г.Набережные Челны по '
#  'просьбе моего доверителя (по доверенности)..- нужны справки для проверки '
#  'гос.служащего. Некая Аделина сказала, что нужно проверить подлинность '
#  'доверенности (мол, Вам по итогу проверки придет смс). г. (12:00-13:50)- '
#  'пришла в Росбанк..(смс все еще жду)...а тут наша ОЧАРОВАТЕЛЬНАЯ Аделина ушла '
#  'в отпуск и забила на мою доверенность (а без чудо Аделины никак)...!Благо, '
#  'появилась некая Х. Г.С., которая сказала, что доверенность проверена и '
#  'последующее сообщение в головной офис от Аделины (по поводу справок) было '
#  'отправлено. г. (15:30-16:40) - гражданка Х. Г.С. проверив свою "аля супер '
#  'почту" промолвила: мдаа..., а справки то не отправили..- видно забили на '
#  'наше обращение. Х. Г.С. пыталась  связаться с головным офисом, но увы '
#  'трубочку так никто и не поднял. г. (16:40-17:10) - написали '
#  'претензию/обращение в Росбанк, заверили печатью и подписью. Х. Г.С. написала '
#  'номер претензии №16178214 и сказала, что по поводу исполнения я могу '
#  'обращаться в контакт-центр (но пояснила, что ранее чем через 5 дней никто не '
#  'ответит). г. (09:00-19:00) - звонила в контакт-центр раз 100..никто не может '
#  'найти обращение (ни по номеру, ни по ФИО)! Звонок в филиал в г.Набережные '
#  'Челны еще более поставил в ступор: А наша Х. Г.С. в отпуске!!!!!!!!! '
#  '(наверное с Аделиной созвонились)!!!НИКТО НЕ МОЖЕТ РЕШИТЬ ПРОБЛЕМУ!!! А '
#  'ПОЭТОМУ: В связи с ограниченным сроком проверки достоверности представленных '
#  'гос.служащим ,,.,,.,,. сведений о доходах и расходах, ТРЕБУЮ предоставить '
#  'сведения (указанные в обращении №16178214) в кратчайшие сроки!!!С '
#  'последующей выдачей их мне нарочно!!!!')
# target                            2
# coloring                       good
# predictions    [0.718, 0.28, 0.001]
# Name: 2370, dtype: object
#
# ('Всем привет,открыл счет в банке для перевода денег на брокерский '
#  'счет,оформил заявку на перевод денег,валютный контроль запросил документы на '
#  'открытие брокерского счета,предоставил их в валютный контроль, и началась '
#  'игра в футбол.Заявка провисела два дня,ни каких звонков со стороны банка,я '
#  'начал бить тревогу,деньги со счета ушли и повисли где то.звонил на горячую '
#  'линию,раз 5,начали футболить то один позвони,то другим,потом сказали а ты '
#  'напиши нам,после переписки выяснилось,что документы каким то образом попали '
#  'в другой департамент, т.е не в валютный контроль,а в дистанционное '
#  'обслуживание.Я не пойму они в разных странах сидят? Но самое интересное что '
#  'после моих мытарств ,мне вернули деньги на мой счет ,и посоветовали '
#  'обратиться в дополнительный офис,видимо центральный ни чем помочь не '
#  'может))) Сейчас нахожусь в командировке ,приеду заберу свои деньги,и Вам '
#  'всем советую не связываться с этим банком,клиентов за людей не считают. Всем '
#  'добра.')
# target                             2
# coloring                        good
# predictions    [0.631, 0.367, 0.003]
# Name: 2583, dtype: object
